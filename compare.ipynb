# %%
import duckdb, pandas as pd
conn = duckdb.connect("IPL_cricket.db")
df = conn.sql("SELECT * FROM matches LIMIT 50").df()
df
# Out:
#    match_id       date                                              venue  \
# 0   1082591 2017-04-05          Rajiv Gandhi International Stadium, Uppal
# 1   1082615 2017-04-22            Maharashtra Cricket Association Stadium
# 2   1082634 2017-05-06          Rajiv Gandhi International Stadium, Uppal
# 3   1082624 2017-04-29            Maharashtra Cricket Association Stadium
# 4   1082614 2017-04-22                                   Wankhede Stadium
# 5   1082631 2017-05-03                                       Eden Gardens
# 6   1082627 2017-04-30          Rajiv Gandhi International Stadium, Uppal
# 7   1082596 2017-04-09          Rajiv Gandhi International Stadium, Uppal
# 8   1082613 2017-04-21                                       Eden Gardens
# 9   1082606 2017-04-16                                   Wankhede Stadium
# 10  1082632 2017-05-04                                   Feroz Shah Kotla
# 11  1082592 2017-04-06            Maharashtra Cricket Association Stadium
# ...

# %%
import duckdb
conn = duckdb.connect("IPL_cricket.db")
print(conn.sql("SHOW TABLES").fetchall())
# Out:
# [('deliveries',), ('matches',), ('ml_features_unified',), ('ml_features_unified_test',), ('ml_features_unified_train',), ('ml_features_unified_val',)]

# %%
conn.close()
